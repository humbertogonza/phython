# %%
### variables ###
my_string_variable = " mi_string_variable"
print(my_string_variable)

my_int_variable = 5
print(my_int_variable)

my_int_to_str_variable = str(my_int_variable)
print(my_int_to_str_variable)
print(type(my_int_to_str_variable))


my_bool_variable = False
print(my_bool_variable)


# concatenacion de variables en un print
print(My_string_variable,My_int_to_str_variable,my_bool_variable)
print("Este es el valor de:", my_bool_variable)

#Alguas funciones del sistema
print(len(my_string_variable))

# variables en una sola linea. ¡cuidado con abusar de esta sintaxis!
name, surname, alias, age, = "Humberto", "Gonzalez Zamora", "Alumno" , 15
print("me llamo:", name, surname, "mi edad es:",
      age, ". Y mi alias es:", alias)


# inputs
name = input('¿cual es tu nombre?')
age = input('¿cuantos años tienes?')
print(name)
print(age)


# cambiamos su tipo
name = 15
age = "Humberto"
print(name)
print(age)

# ¿Formamos el tipo?
address: str = "mi direccion"
address = True
address = 5
address = 1.2
print(type(address))
# Out:
#  mi_string_variable
# 5
# 5
# <class 'str'>
# False
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-21cb4f23c395> in <cell line: 18>()
#      16
#      17 # concatenacion de variables en un print
# ---> 18 print(My_string_variable,My_int_to_str_variable,my_bool_variable)
#      19 print("Este es el valor de:", my_bool_variable)
#      20
#
# NameError: name 'My_string_variable' is not defined
