# %%
### Strings ###
my_string = "my String"
my_other_string = "my_otro string"

print(len(my_string))
print(len(my_other_string))
print(my_tring + " " + my_other_string)

my_new_line_string = "este es un string con salta en linea"
print(my_new_line_string)

my_tab_string = "tEste es un string con tabulacion"
print(my_tab_string)

my_scape_string = "tEste es un string  n escapado"
print(my_scape_string)


# Formateo

name, surname, age = "Humberto" , "Gonzalez", 15
print("my_nombre es {} {} y my edad es {}".format(name, surname, age))
print("my nombre es %s %s y mi edad es %d" % (name, surname, age))
print("my nombre es" + name + "" + surname + " y mi edad es " + str(age))
print(f"my nombre es {name}  {surname} y mi edad es{age}")


# Desenpaquetado de caracteres

# Divicion

language_slice = language[1:3]
print(language_slice)

language_slice = language[1:]
print(language_slice)

language_slice = language[-2]
print(language_slice)

language_slice = language [0 : 6 : 2]
print(language_slice)


# Reverce

reverced_language = language[::-1]
print(reversed_language)

# Funciones del lenguaje
#print(language.capitalize())
#print(language.upper())
#print(language.count("t"))
#print(language.isnumeric())
#print("1".isnumeric())
#print(language.lower())
#print(language.lower().insupper())
